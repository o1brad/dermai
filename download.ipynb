# %% [markdown]
# ## Downloading images
#
# After having scraped all of the image URLs and their corresponding labels, we need to download the images and store them in folders, MNIST style.

# %%
## Importing the labels

import pickle

labeled_urls = pickle.load(open("tagged_image_urls.pickle", "rb"))

labeled_urls[:5]
# Out:
# [('Seborrheic-Keratoses-Ruff',
#   ['http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-00134.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-1.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-10.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-100.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-101.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-102.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-103.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-104.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-105.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-106.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-107.jpg',
#    'http://www.dermnet.com/dn2/allJPG3/seborrheic-keratoses-ruff-108.jpg',
# ...

# %% [markdown]
# ### Downloading the images

# %%
# !pip install fastai
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/16/12/b8c2374b15d5d77b28f4d09556510cf7b47bf2364d06913c97be633da7b0/fastai-1.0.42-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/4a/bd/eee1157fc2d8514970b345d69cb9975dcd1e42cd7e61146ed841f6e68309/typing-3.6.6-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/2f/77/63ebd4038b7acf95daceb3e623532d0b4e2921fb0d875fdd68b1275aa7ec/spacy-2.0.18-cp37-cp37m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/b1/a6/414a603f24eee6df88da1d087fe358a13d32f8d571eba71520f4620d96be/torch-1.0.1-cp37-none-macosx_10_7_x86_64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/78/57/24a5e20f4a357f7f1c90dd5250071951c832b2480fd4fefd7be48edf4180/fastprogress-0.1.18-py3-none-any.whl
# ...

# %%
pip

# %%
import urllib.request
from pathlib import Path
import os
from fastai import *

# %%
cwd = os.getcwd()
base_path = Path(cwd + '/data/')

for label, urls in labeled_urls:
    folder = base_path/label
    for url in urls:
        download_images()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-142067b20809> in <module>()
#       5     folder = base_path/label
#       6     for url in urls:
# ----> 7         download_images()
#       8
#
# NameError: name 'download_images' is not defined
